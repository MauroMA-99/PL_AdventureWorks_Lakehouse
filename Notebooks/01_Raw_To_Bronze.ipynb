# %%
df_customer = spark.read.parquet(
    "abfss://adlsdatamau@sadp203mau.dfs.core.windows.net/01-Bronze/SalesLT.Customer.parquet"
)

df_address = spark.read.parquet(
    "abfss://adlsdatamau@sadp203mau.dfs.core.windows.net/01-Bronze/SalesLT.Address.parquet"
)

df_customeraddress = spark.read.parquet(
    "abfss://adlsdatamau@sadp203mau.dfs.core.windows.net/01-Bronze/SalesLT.CustomerAddress.parquet"
)

df_product = spark.read.parquet(
    "abfss://adlsdatamau@sadp203mau.dfs.core.windows.net/01-Bronze/SalesLT.Product.parquet"
)

df_productCategory = spark.read.parquet(
    "abfss://adlsdatamau@sadp203mau.dfs.core.windows.net/01-Bronze/SalesLT.ProductCategory.parquet"
)

df_productModel = spark.read.parquet(
    "abfss://adlsdatamau@sadp203mau.dfs.core.windows.net/01-Bronze/SalesLT.ProductModel.parquet"
)

df_salesOrderDetail = spark.read.parquet(
    "abfss://adlsdatamau@sadp203mau.dfs.core.windows.net/01-Bronze/SalesLT.SalesOrderDetail.parquet"
)

df_salesOrderHeader = spark.read.parquet(
    "abfss://adlsdatamau@sadp203mau.dfs.core.windows.net/01-Bronze/SalesLT.SalesOrderHeader.parquet"
)
# Out:
# StatementMeta(SparkProyecto, 1, 4, Finished, Available, Finished, False)

# %%
spark.sql("IF NOT EXISTS CREATE DATABASE bronze")
spark.sql("IF NOT EXISTS CREATE DATABASE silver")
spark.sql("IF NOT EXISTS CREATE DATABASE gold")
# Out:
# StatementMeta(, 1, -1, Cancelled, , Cancelled, True)

# %%
df_customer.write.mode("overwrite").saveAsTable("bronze.Customer")
df_address.write.mode("overwrite").saveAsTable("bronze.Address")
df_customeraddress.write.mode("overwrite").saveAsTable("bronze.CustomerAddress")
df_product.write.mode("overwrite").saveAsTable("bronze.Product")
df_productCategory.write.mode("overwrite").saveAsTable("bronze.ProductCategory")
df_productModel.write.mode("overwrite").saveAsTable("bronze.ProductModel")
df_salesOrderDetail.write.mode("overwrite").saveAsTable("bronze.SalesOrderDetail")
df_salesOrderHeader.write.mode("overwrite").saveAsTable("bronze.SalesOrderHeader")
# Out:
# StatementMeta(SparkProyecto, 1, 14, Finished, Available, Finished, False)
